# %% [markdown]
# # MATCH_SUMMARY

# %%
import pandas as pd

# %%
df = pd.read_html("https://www.espncricinfo.com/records/tournament/team-match-results/indian-premier-league-2023-15129")

# %%
d = pd.DataFrame(df[0])

# %%
d.columns
# Out:
# Index(['Team 1', 'Team 2', 'Winner', 'Margin', 'Ground', 'Match Date',
#        'Scorecard'],
#       dtype='object')

# %%
d.shape
# Out:
# (74, 7)

# %%
d
# Out:
#           Team 1       Team 2        Winner     Margin     Ground  \
# 0         Titans  Super Kings        Titans  5 wickets  Ahmedabad
# 1   Punjab Kings          KKR  Punjab Kings     7 runs     Mohali
# 2   Super Giants     Capitals  Super Giants    50 runs    Lucknow
# 3      Sunrisers       Royals        Royals    72 runs  Hyderabad
# 4            RCB       Mumbai           RCB  8 wickets  Bengaluru
# ..           ...          ...           ...        ...        ...
# 69           RCB       Titans        Titans  6 wickets  Bengaluru
# 70   Super Kings       Titans   Super Kings    15 runs    Chennai
# 71  Super Giants       Mumbai        Mumbai    81 runs    Chennai
# 72        Titans       Mumbai        Titans    62 runs  Ahmedabad
# 73        Titans  Super Kings   Super Kings  5 wickets  Ahmedabad
#
#          Match Date Scorecard
# 0      Mar 31, 2023  Twenty20
# 1       Apr 1, 2023  Twenty20
# 2       Apr 1, 2023  Twenty20
# 3       Apr 2, 2023  Twenty20
# ...

# %%
Match_ID = []
for i in range(0,len(d)):
    s=str(i)
    if i<10:
        p = "#230"
        ID = p+s
        Match_ID.append(ID)
    else:
        p1 = "#23"
        ID1 = p1+s
        Match_ID.append(ID1)
d["Match_ID"] = Match_ID

# %%
d = d.drop("Scorecard", axis=1)

# %%
d["Team 1"].unique()
# Out:
# array(['Titans', 'Punjab Kings', 'Super Giants', 'Sunrisers', 'RCB',
#        'Super Kings', 'Capitals', 'Royals', 'KKR', 'Mumbai'], dtype=object)

# %%
d["Team 2"].unique()
# Out:
# array(['Super Kings', 'KKR', 'Capitals', 'Royals', 'Mumbai',
#        'Super Giants', 'Titans', 'Punjab Kings', 'RCB', 'Sunrisers'],
#       dtype=object)

# %%
d["Winner"].unique()
# Out:
# array(['Titans', 'Punjab Kings', 'Super Giants', 'Royals', 'RCB',
#        'Super Kings', 'KKR', 'Sunrisers', 'Mumbai', 'Capitals',
#        'no result'], dtype=object)

# %%
d[d["Winner"]=="no result"]
# Out:
#           Team 1       Team 2     Winner Margin   Ground   Match Date Match_ID
# 44  Super Giants  Super Kings  no result      -  Lucknow  May 3, 2023    #2344

# %%
for j in range(len(d)):
    if d["Winner"][j]=="no result":
        d = d.drop(j, axis=0)

# %%
d.head(45)
# Out:
#           Team 1        Team 2        Winner     Margin        Ground  \
# 0         Titans   Super Kings        Titans  5 wickets     Ahmedabad
# 1   Punjab Kings           KKR  Punjab Kings     7 runs        Mohali
# 2   Super Giants      Capitals  Super Giants    50 runs       Lucknow
# 3      Sunrisers        Royals        Royals    72 runs     Hyderabad
# 4            RCB        Mumbai           RCB  8 wickets     Bengaluru
# 5    Super Kings  Super Giants   Super Kings    12 runs       Chennai
# 6       Capitals        Titans        Titans  6 wickets         Delhi
# 7         Royals  Punjab Kings  Punjab Kings     5 runs      Guwahati
# 8            KKR           RCB           KKR    81 runs  Eden Gardens
# 9   Super Giants     Sunrisers  Super Giants  5 wickets       Lucknow
# 10        Royals      Capitals        Royals    57 runs      Guwahati
# 11        Mumbai   Super Kings   Super Kings  7 wickets      Wankhede
# ...

# %%
d["Team 1"].unique()
# Out:
# array(['Titans', 'Punjab Kings', 'Super Giants', 'Sunrisers', 'RCB',
#        'Super Kings', 'Capitals', 'Royals', 'KKR', 'Mumbai'], dtype=object)

# %%
d.replace("Titans","Gujarat Titans", inplace=True)
d.replace("Super Giants","Lucknow Super Giants", inplace=True)
d.replace("Sunrisers","Sunrisers Hyderabad", inplace=True)
d.replace("RCB","Royal Challengers Bangalore", inplace=True)
d.replace("Super Kings","Chennai Super Kings", inplace=True)
d.replace("Capitals","Delhi Capitals", inplace=True)
d.replace("Royals","Rajastan Royals", inplace=True)
d.replace("KKR","Kolkata Knight Riders", inplace=True)
d.replace("Mumbai","Mumbai Indians", inplace=True)

# %%
d.head()
# Out:
#                         Team 1                 Team 2  \
# 0               Gujarat Titans    Chennai Super Kings
# 1                 Punjab Kings  Kolkata Knight Riders
# 2         Lucknow Super Giants         Delhi Capitals
# 3          Sunrisers Hyderabad        Rajastan Royals
# 4  Royal Challengers Bangalore         Mumbai Indians
#
#                         Winner     Margin     Ground    Match Date Match_ID
# 0               Gujarat Titans  5 wickets  Ahmedabad  Mar 31, 2023    #2300
# 1                 Punjab Kings     7 runs     Mohali   Apr 1, 2023    #2301
# 2         Lucknow Super Giants    50 runs    Lucknow   Apr 1, 2023    #2302
# 3              Rajastan Royals    72 runs  Hyderabad   Apr 2, 2023    #2303
# 4  Royal Challengers Bangalore  8 wickets  Bengaluru   Apr 2, 2023    #2304

# %%
d.to_csv("Match_Summary.csv")

# %% [markdown]
# # BATTING_SUMMARY

# %%
r = pd.read_html("https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/gujarat-titans-vs-chennai-super-kings-1st-match-1359475/full-scorecard")

# %%
df_b = pd.DataFrame(r[0])

# %%
df_b
# Out:
#                                               BATTING  \
# 0                                        Devon Conway
# 1                                                 NaN
# 2                                     Ruturaj Gaikwad
# 3                                                 NaN
# 4                                           Moeen Ali
# 5                                                 NaN
# 6                                          Ben Stokes
# 7                                                 NaN
# 8                                       Ambati Rayudu
# 9                                                 NaN
# 10                                        Shivam Dube
# 11                                                NaN
# 12                                    Ravindra Jadeja
# 13                                                NaN
# 14                                      MS Dhoni (c)†
# 15                                   Mitchell Santner
# ...

# %%
df_b = df_b.drop(["Unnamed: 8","Unnamed: 9"],axis=1)

# %%
df_b = df_b.dropna()

# %%
df_b
# Out:
#                                               BATTING  \
# 0                                        Devon Conway
# 2                                     Ruturaj Gaikwad
# 4                                           Moeen Ali
# 6                                          Ben Stokes
# 8                                       Ambati Rayudu
# 10                                        Shivam Dube
# 12                                    Ravindra Jadeja
# 14                                      MS Dhoni (c)†
# 15                                   Mitchell Santner
# 18  Did not bat: Deepak Chahar, Rajvardhan Hangarg...
# 19  Fall of wickets: 1-14 (Devon Conway, 2.2 ov), ...
#
#                                            Unnamed: 1  \
# 0                                    b Mohammed Shami
# 2                             c Shubman Gill b Joseph
# 4                               c †Saha b Rashid Khan
# 6                               c †Saha b Rashid Khan
# ...

# %%
df_b = df_b.iloc[:-2]

# %%
df_b
# Out:
#              BATTING                      Unnamed: 1   R   B  M 4s 6s      SR
# 0       Devon Conway                b Mohammed Shami   1   6  -  0  0   16.66
# 2    Ruturaj Gaikwad         c Shubman Gill b Joseph  92  50  -  4  9  184.00
# 4          Moeen Ali           c †Saha b Rashid Khan  23  17  -  4  1  135.29
# 6         Ben Stokes           c †Saha b Rashid Khan   7   6  -  1  0  116.66
# 8      Ambati Rayudu                        b Little  12  12  -  0  1  100.00
# 10       Shivam Dube  c Rashid Khan b Mohammed Shami  19  18  -  0  1  105.55
# 12   Ravindra Jadeja              c Shankar b Joseph   1   2  -  0  0   50.00
# 14     MS Dhoni (c)†                         not out  14   7  -  1  1  200.00
# 15  Mitchell Santner                         not out   1   3  -  0  0   33.33

# %%
df_b["Out/No Out"]= df_b["Unnamed: 1"].apply(lambda x: "Out" if x!= "not out" else "Not out")
# Out:
# C:\Users\Revanth\AppData\Local\Temp\ipykernel_23820\1407997299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_b["Out/No Out"]= df_b["Unnamed: 1"].apply(lambda x: "Out" if x!= "not out" else "Not out")

# %%
df_b
# Out:
#              BATTING                      Unnamed: 1   R   B  M 4s 6s      SR  \
# 0       Devon Conway                b Mohammed Shami   1   6  -  0  0   16.66
# 2    Ruturaj Gaikwad         c Shubman Gill b Joseph  92  50  -  4  9  184.00
# 4          Moeen Ali           c †Saha b Rashid Khan  23  17  -  4  1  135.29
# 6         Ben Stokes           c †Saha b Rashid Khan   7   6  -  1  0  116.66
# 8      Ambati Rayudu                        b Little  12  12  -  0  1  100.00
# 10       Shivam Dube  c Rashid Khan b Mohammed Shami  19  18  -  0  1  105.55
# 12   Ravindra Jadeja              c Shankar b Joseph   1   2  -  0  0   50.00
# 14     MS Dhoni (c)†                         not out  14   7  -  1  1  200.00
# 15  Mitchell Santner                         not out   1   3  -  0  0   33.33
#
#    Out/No Out
# 0         Out
# 2         Out
# 4         Out
# 6         Out
# 8         Out
# 10        Out
# 12        Out
# 14    Not out
# 15    Not out

# %%
df_b["Match_ID"] = d.iloc[0,6]
# Out:
# C:\Users\Revanth\AppData\Local\Temp\ipykernel_23820\3454294811.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_b["Match_ID"] = d.iloc[0,6]

# %%
df_b
# Out:
#              BATTING                      Unnamed: 1   R   B  M 4s 6s      SR  \
# 0       Devon Conway                b Mohammed Shami   1   6  -  0  0   16.66
# 2    Ruturaj Gaikwad         c Shubman Gill b Joseph  92  50  -  4  9  184.00
# 4          Moeen Ali           c †Saha b Rashid Khan  23  17  -  4  1  135.29
# 6         Ben Stokes           c †Saha b Rashid Khan   7   6  -  1  0  116.66
# 8      Ambati Rayudu                        b Little  12  12  -  0  1  100.00
# 10       Shivam Dube  c Rashid Khan b Mohammed Shami  19  18  -  0  1  105.55
# 12   Ravindra Jadeja              c Shankar b Joseph   1   2  -  0  0   50.00
# 14     MS Dhoni (c)†                         not out  14   7  -  1  1  200.00
# 15  Mitchell Santner                         not out   1   3  -  0  0   33.33
#
#    Out/No Out Match_ID
# 0         Out    #2300
# 2         Out    #2300
# 4         Out    #2300
# 6         Out    #2300
# 8         Out    #2300
# 10        Out    #2300
# ...

# %%
df_b["Batting_POS"] = range(1,len(df_b)+1)
# Out:
# C:\Users\Revanth\AppData\Local\Temp\ipykernel_23820\2508135598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_b["Batting_POS"] = range(1,len(df_b)+1)

# %%
df_b
# Out:
#              BATTING                      Unnamed: 1   R   B  M 4s 6s      SR  \
# 0       Devon Conway                b Mohammed Shami   1   6  -  0  0   16.66
# 2    Ruturaj Gaikwad         c Shubman Gill b Joseph  92  50  -  4  9  184.00
# 4          Moeen Ali           c †Saha b Rashid Khan  23  17  -  4  1  135.29
# 6         Ben Stokes           c †Saha b Rashid Khan   7   6  -  1  0  116.66
# 8      Ambati Rayudu                        b Little  12  12  -  0  1  100.00
# 10       Shivam Dube  c Rashid Khan b Mohammed Shami  19  18  -  0  1  105.55
# 12   Ravindra Jadeja              c Shankar b Joseph   1   2  -  0  0   50.00
# 14     MS Dhoni (c)†                         not out  14   7  -  1  1  200.00
# 15  Mitchell Santner                         not out   1   3  -  0  0   33.33
#
#    Out/No Out Match_ID  Batting_POS
# 0         Out    #2300            1
# 2         Out    #2300            2
# 4         Out    #2300            3
# 6         Out    #2300            4
# ...

# %%
df_b = df_b.drop(["Unnamed: 1","M"],axis=1)

# %%
df_b
# Out:
#              BATTING   R   B 4s 6s      SR Out/No Out Match_ID  Batting_POS
# 0       Devon Conway   1   6  0  0   16.66        Out    #2300            1
# 2    Ruturaj Gaikwad  92  50  4  9  184.00        Out    #2300            2
# 4          Moeen Ali  23  17  4  1  135.29        Out    #2300            3
# 6         Ben Stokes   7   6  1  0  116.66        Out    #2300            4
# 8      Ambati Rayudu  12  12  0  1  100.00        Out    #2300            5
# 10       Shivam Dube  19  18  0  1  105.55        Out    #2300            6
# 12   Ravindra Jadeja   1   2  0  0   50.00        Out    #2300            7
# 14     MS Dhoni (c)†  14   7  1  1  200.00    Not out    #2300            8
# 15  Mitchell Santner   1   3  0  0   33.33    Not out    #2300            9

# %%
df_b["Match"] = d.iloc[0,0]+" vs "+d.iloc[0,1]

# %%
df_b
# Out:
#              BATTING   R   B 4s 6s      SR Out/No Out Match_ID  Batting_POS  \
# 0       Devon Conway   1   6  0  0   16.66        Out    #2300            1
# 2    Ruturaj Gaikwad  92  50  4  9  184.00        Out    #2300            2
# 4          Moeen Ali  23  17  4  1  135.29        Out    #2300            3
# 6         Ben Stokes   7   6  1  0  116.66        Out    #2300            4
# 8      Ambati Rayudu  12  12  0  1  100.00        Out    #2300            5
# 10       Shivam Dube  19  18  0  1  105.55        Out    #2300            6
# 12   Ravindra Jadeja   1   2  0  0   50.00        Out    #2300            7
# 14     MS Dhoni (c)†  14   7  1  1  200.00    Not out    #2300            8
# 15  Mitchell Santner   1   3  0  0   33.33    Not out    #2300            9
#
#                                     Match
# 0   Gujarat Titans vs Chennai Super Kings
543/full-scorecard","https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/royal-challengers-bangalore-vs-gujarat-titans-70th-match-1359544/full-scorecard","https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/chennai-super-kings-vs-gujarat-titans-qualifier-1-1370350/full-scorecard","https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/lucknow-super-giants-vs-mumbai-indians-eliminator-1370351/full-scorecard","https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/gujarat-titans-vs-mumbai-indians-qualifier-2-1370352/full-scorecard","https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/gujarat-titans-vs-chennai-super-kings-final-1370353/full-scorecard"]

# %%
len(link)
# Out:
# 73

# %%
df_bs = pd.DataFrame(columns=["Match","Batting_POS","BATTING","R","B","4s","6s","SR","Out/No Out"])

# %%
for i in range(0,len(link)):
    r = pd.read_html(link[i])
    df_b = pd.DataFrame(r[0])
    df_b = df_b.drop_duplicates()
    df_b = df_b.drop(["Unnamed: 8","Unnamed: 9"],axis=1)
    df_b = df_b.dropna()
    df_b = df_b.iloc[:-2]
    df_b["Out/No Out"]= df_b["Unnamed: 1"].apply(lambda x: "Out" if x!= "not out" else "Not out")
    df_b["Match_ID"] = d.iloc[i,6]
    df_b["Batting_POS"] = range(1,len(df_b)+1)
    df_b = df_b.drop(["Unnamed: 1","M"],axis=1)
    df_b["Match"] = d.iloc[i,0]+" vs "+d.iloc[i,1]
    df_bs = pd.concat([df_bs,df_b])
    df_b = pd.DataFrame(r[2])
    df_b = df_b.drop_duplicates()
    df_b = df_b.drop(["Unnamed: 8","Unnamed: 9"],axis=1)
    df_b = df_b.dropna()
    df_b = df_b.iloc[:-2]
    df_b["Out/No Out"]= df_b["Unnamed: 1"].apply(lambda x: "Out" if x!= "not out" else "Not out")
    df_b["Match_ID"] = d.iloc[i,6]
    df_b["Batting_POS"] = range(1,len(df_b)+1)
    df_b = df_b.drop(["Unnamed: 1","M"],axis=1)
    df_b["Match"] = d.iloc[i,0]+" vs "+d.iloc[i,1]
    df_bs = pd.concat([df_bs,df_b])

# %%
df_bs.head(10)
# Out:
#                                     Match Batting_POS            BATTING   R  \
# 0   Gujarat Titans vs Chennai Super Kings           1       Devon Conway   1
# 2   Gujarat Titans vs Chennai Super Kings           2    Ruturaj Gaikwad  92
# 4   Gujarat Titans vs Chennai Super Kings           3          Moeen Ali  23
# 6   Gujarat Titans vs Chennai Super Kings           4         Ben Stokes   7
# 8   Gujarat Titans vs Chennai Super Kings           5      Ambati Rayudu  12
# 10  Gujarat Titans vs Chennai Super Kings           6        Shivam Dube  19
# 12  Gujarat Titans vs Chennai Super Kings           7    Ravindra Jadeja   1
# 14  Gujarat Titans vs Chennai Super Kings           8      MS Dhoni (c)†  14
# 15  Gujarat Titans vs Chennai Super Kings           9   Mitchell Santner   1
# 0   Gujarat Titans vs Chennai Super Kings           1  Wriddhiman Saha †  25
#
#      B 4s 6s      SR Out/No Out Match_ID
# 0    6  0  0   16.66        Out    #2300
# ...

# %%
df_bs["BATTING"] = df_bs["BATTING"].apply(lambda x: x.replace("(c)",""))
df_bs["BATTING"] = df_bs["BATTING"].apply(lambda x: x.replace("†",""))

# %%
df_bs.to_csv("IPL2023_Batting_Summary.csv")

# %% [markdown]
# # Bowling_Summary

# %%
r = pd.read_html("https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/gujarat-titans-vs-chennai-super-kings-1st-match-1359475/full-scorecard")

# %%
df_bo = pd.DataFrame(r[1])

# %%
df_bo
# Out:
#                                              BOWLING  \
# 0                                     Mohammed Shami
# 1  2.2 to DP Conway, Shami breaches the defences ...
# 2                                      Hardik Pandya
# 3                                        Josh Little
# 4  12.5 to AT Rayudu, Maiden IPL wicket for Josh ...
# 5                                        Rashid Khan
# 6  5.5 to MM Ali, Rashid strikes back, Moeen has ...
# 7                                     Alzarri Joseph
# 8  17.1 to RD Gaikwad, Joseph misses the yorker, ...
# 9                                         Yash Dayal
#
#                                                    O  \
# 0                                                  4
# 1  2.2 to DP Conway, Shami breaches the defences ...
# 2                                                  3
# 3                                                  4
# 4  12.5 to AT Rayudu, Maiden IPL wicket for Josh ...
# 5                                                  4
# ...

# %%
for t in range(len(df_bo)):
        if df_bo["BOWLING"][t]==df_bo["O"][t]:
            df_bo = df_bo.drop(t)

# %%
df_bo
# Out:
#           BOWLING  O  M   R  W   ECON  0s 4s 6s WD NB
# 0  Mohammed Shami  4  0  29  2   7.25  13  2  2  0  1
# 2   Hardik Pandya  3  0  28  0   9.33   6  2  2  0  0
# 3     Josh Little  4  0  41  1  10.25  10  4  3  0  0
# 5     Rashid Khan  4  0  26  2   6.50  10  2  1  0  0
# 7  Alzarri Joseph  4  0  33  2   8.25   8  0  3  0  0
# 9      Yash Dayal  1  0  14  0  14.00   2  0  2  0  0

# %%
df_bos = pd.DataFrame(columns=["Match","BOWLING","O","M","R","W","ECON","0s","4s","6s","WD","NB"])

# %%
for j in range(0,len(link)):
    r = pd.read_html(link[j])
    df_bo = pd.DataFrame(r[1])
    df_bo = df_bo.drop_duplicates()
    df_bo["Match_ID"] = d.iloc[j,6]
    df_bo["Match"] = d.iloc[j,0]+" vs "+d.iloc[j,1]
    for t in range(len(df_bo)):
        if df_bo["BOWLING"][t]==df_bo["O"][t]:
            df_bo = df_bo.drop(t)
    df_bos = pd.concat([df_bos,df_bo])
    df_bo = pd.DataFrame(r[3])
    df_bo = df_bo.drop_duplicates()
    df_bo["Match_ID"] = d.iloc[j,6]
    df_bo["Match"] = d.iloc[j,0]+" vs "+d.iloc[j,1]
    for t in range(len(df_bo)):
        if df_bo["BOWLING"][t]==df_bo["O"][t]:
            df_bo = df_bo.drop(t)
    df_bos = pd.concat([df_bos,df_bo])

# %%
df_bos.head(10)
# Out:
#                                    Match                 BOWLING    O  M   R  \
# 0  Gujarat Titans vs Chennai Super Kings          Mohammed Shami    4  0  29
# 2  Gujarat Titans vs Chennai Super Kings           Hardik Pandya    3  0  28
# 3  Gujarat Titans vs Chennai Super Kings             Josh Little    4  0  41
# 5  Gujarat Titans vs Chennai Super Kings             Rashid Khan    4  0  26
link_srh = ["http://www.espncricinfo.com/player/mayank-agarwal-398438","http://www.espncricinfo.com/player/fazalhaq-farooqi-974175","http://www.espncricinfo.com/player/heinrich-klaasen-436757","http://www.espncricinfo.com/player/mayank-markande-1081442","http://www.espncricinfo.com/player/glenn-phillips-823509","http://www.espncricinfo.com/player/abdul-samad-1175485","http://www.espncricinfo.com/player/anmolpreet-singh-851261","http://www.espncricinfo.com/player/rahul-tripathi-446763","http://www.espncricinfo.com/player/upendra-yadav-732269","http://www.espncricinfo.com/player/harry-brook-911707","http://www.espncricinfo.com/player/akeal-hosein-530812","http://www.espncricinfo.com/player/bhuvneshwar-kumar-326016","http://www.espncricinfo.com/player/aiden-markram-600498","http://www.espncricinfo.com/player/adil-rashid-244497","http://www.espncricinfo.com/player/abhishek-sharma-1070183","http://www.espncricinfo.com/player/washington-sundar-719715","http://www.espncricinfo.com/player/kartik-tyagi-1122918","http://www.espncricinfo.com/player/mayank-dagar-942367","http://www.espncricinfo.com/player/marco-jansen-696401","http://www.espncricinfo.com/player/umran-malik-1246528","https://www.espncricinfo.com/player/t-natarajan-802575","http://www.espncricinfo.com/player/nitish-kumar-reddy-1175496","http://www.espncricinfo.com/player/vivrant-sharma-1252370","http://www.espncricinfo.com/player/sanvir-singh-1132219","http://www.espncricinfo.com/player/samarth-vyas-853859"]

# %%
PlayerName = []
BattingStyle = []
BowlingStyle = []
PlayingRole = []
Teams = []

# %%
import requests
from bs4 import BeautifulSoup

# %%
def battingstyle(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        p = soup.find_all('p')
        for i in range(len(p)):
            if p[i].text == "Batting Style":
                BattingStyle.append(p[i+1].text)
                break
        else:
            BattingStyle.append("NA")       
                
def bowlingstyle(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        pb = soup.find_all('p')
        for j in range(len(pb)):
            if pb[j].text == "Bowling Style":
                BowlingStyle.append(pb[j+1].text)
                break
        else:
            BowlingStyle.append("NA")
            
def playingrole(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        pr = soup.find_all('p')
        for k in range(len(pr)):
            if pr[k].text == "Playing Role":
                PlayingRole.append(pr[k+1].text)
                break
        else:
            PlayingRole.append("NA")

# %%
import requests
from bs4 import BeautifulSoup
def scrape_webpage(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        headings = soup.find_all('h1')
        p = soup.find_all('p')
        #a = soup.find_all('a')
        for heading in headings:
            PlayerName.append(heading.text)
        battingstyle(url)
        bowlingstyle(url)
        playingrole(url)
    else:
        print("Error:", response.status_code)

# %%
for i in link_mi:        
    scrape_webpage(i)
    Teams.append("Mumbai Indians")

# %%
for i in link_csk:        
    scrape_webpage(i)
    Teams.append("Chennai Super Kings")

# %%
for i in link_gt:        
    scrape_webpage(i)
    Teams.append("Gujarat Titans")

# %%
for i in link_dc:        
    scrape_webpage(i)
    Teams.append("Delhi Capitals")

# %%
for i in link_kkr:        
    scrape_webpage(i)
    Teams.append("Kolkata Knight Riders")

# %%
for i in link_lsg:        
    scrape_webpage(i)
    Teams.append("Lucknow Super Giants")

# %%
for i in link_pbks:        
    scrape_webpage(i)
    Teams.append("Punjab Kings")

# %%
for i in link_rr:        
    scrape_webpage(i)
    Teams.append("Rajastan Royals")

# %%
for i in link_rcb:        
    scrape_webpage(i)
    Teams.append("Royal Challengers Bangalore")

# %%
for i in link_srh:        
    scrape_webpage(i)
    Teams.append("Sunrisers Hyderabad")

# %%
df_m = pd.DataFrame()
df_m["PlayerName"]=PlayerName
df_m["BattingStyle"]=BattingStyle
df_m["BowlingStyle"]=BowlingStyle
df_m["PlayingRole"]=PlayingRole
df_m["Team"]=Teams

df_m
# Out:
#              PlayerName    BattingStyle           BowlingStyle  \
# 0          Rohit Sharma  Right hand Bat     Right arm Offbreak
# 1     Jason Behrendorff  Right hand Bat   Left arm Fast medium
# 2             Tim David  Right hand Bat     Right arm Offbreak
# 3           Duan Jansen  Right hand Bat          Left arm Fast
# 4           Arshad Khan   Left hand Bat        Left arm Medium
# ..                  ...             ...                    ...
# 231         T Natarajan   Left hand Bat        Left arm Medium
# 232  Nitish Kumar Reddy  Right hand Bat  Right arm Medium fast
# 233      Vivrant Sharma   Left hand Bat        Legbreak Googly
# 234        Sanvir Singh  Right hand Bat       Right arm Medium
# 235        Samarth Vyas  Right hand Bat        Legbreak Googly
#
#              PlayingRole                 Team
# 0       Top order Batter       Mumbai Indians
# 1                 Bowler       Mumbai Indians
# 2    Middle order Batter       Mumbai Indians
# ...

# %%
df_m.to_csv("IPL_2023_Player.csv")

# %% [markdown]
# # Data Cleaning

# %%
df_ms = pd.read_csv("Match_Summary.csv")

# %%
df_ms.head()
# Out:
#    Unnamed: 0                       Team 1                 Team 2  \
# 0           0               Gujarat Titans    Chennai Super Kings
# 1           1                 Punjab Kings  Kolkata Knight Riders
# 2           2         Lucknow Super Giants         Delhi Capitals
# 3           3          Sunrisers Hyderabad        Rajastan Royals
# 4           4  Royal Challengers Bangalore         Mumbai Indians
#
#                         Winner     Margin     Ground    Match Date Match_ID
# 0               Gujarat Titans  5 wickets  Ahmedabad  Mar 31, 2023    #2300
# 1                 Punjab Kings     7 runs     Mohali   Apr 1, 2023    #2301
# 2         Lucknow Super Giants    50 runs    Lucknow   Apr 1, 2023    #2302
# 3              Rajastan Royals    72 runs  Hyderabad   Apr 2, 2023    #2303
# 4  Royal Challengers Bangalore  8 wickets  Bengaluru   Apr 2, 2023    #2304

# %%
df_ms.drop("Unnamed: 0", axis=1,inplace=True)

# %%
df_ms.head()
# Out:
#                         Team 1                 Team 2  \
# 0               Gujarat Titans    Chennai Super Kings
# 1                 Punjab Kings  Kolkata Knight Riders
# 2         Lucknow Super Giants         Delhi Capitals
# 3          Sunrisers Hyderabad        Rajastan Royals
# 4  Royal Challengers Bangalore         Mumbai Indians
#
#                         Winner     Margin     Ground    Match Date Match_ID
# 0               Gujarat Titans  5 wickets  Ahmedabad  Mar 31, 2023    #2300
# 1                 Punjab Kings     7 runs     Mohali   Apr 1, 2023    #2301
# 2         Lucknow Super Giants    50 runs    Lucknow   Apr 1, 2023    #2302
# 3              Rajastan Royals    72 runs  Hyderabad   Apr 2, 2023    #2303
# 4  Royal Challengers Bangalore  8 wickets  Bengaluru   Apr 2, 2023    #2304

# %%
df_bs.head()
# Out:
#                                    Match Batting_POS          BATTING   R   B  \
# 0  Gujarat Titans vs Chennai Super Kings           1     Devon Conway   1   6
# 2  Gujarat Titans vs Chennai Super Kings           2  Ruturaj Gaikwad  92  50
# 4  Gujarat Titans vs Chennai Super Kings           3        Moeen Ali  23  17
# 6  Gujarat Titans vs Chennai Super Kings           4       Ben Stokes   7   6
# 8  Gujarat Titans vs Chennai Super Kings           5    Ambati Rayudu  12  12
#
#   4s 6s      SR Out/No Out Match_ID
# 0  0  0   16.66        Out    #2300
# 2  4  9  184.00        Out    #2300
# 4  4  1  135.29        Out    #2300
# 6  1  0  116.66        Out    #2300
# 8  0  1  100.00        Out    #2300

# %%
df_bos.head()
# Out:
#                                    Match         BOWLING  O  M   R  W   ECON  \
# 0  Gujarat Titans vs Chennai Super Kings  Mohammed Shami  4  0  29  2   7.25
# 2  Gujarat Titans vs Chennai Super Kings   Hardik Pandya  3  0  28  0   9.33
# 3  Gujarat Titans vs Chennai Super Kings     Josh Little  4  0  41  1  10.25
# 5  Gujarat Titans vs Chennai Super Kings     Rashid Khan  4  0  26  2   6.50
# 7  Gujarat Titans vs Chennai Super Kings  Alzarri Joseph  4  0  33  2   8.25
#
#    0s 4s 6s WD NB Match_ID
# 0  13  2  2  0  1    #2300
# 2   6  2  2  0  0    #2300
# 3  10  4  3  0  0    #2300
# 5  10  2  1  0  0    #2300
# 7   8  0  3  0  0    #2300

# %%
df_pl = pd.read_csv("IPL_2023_Player.csv")

# %%
df_pl.head()
# Out:
#    Unnamed: 0         PlayerName    BattingStyle          BowlingStyle  \
# 0           0       Rohit Sharma  Right hand Bat    Right arm Offbreak
# 1           1  Jason Behrendorff  Right hand Bat  Left arm Fast medium
# 2           2          Tim David  Right hand Bat    Right arm Offbreak
# 3           3        Duan Jansen  Right hand Bat         Left arm Fast
# 4           4        Arshad Khan   Left hand Bat       Left arm Medium
#
#            PlayingRole            Team
# 0     Top order Batter  Mumbai Indians
# 1               Bowler  Mumbai Indians
# 2  Middle order Batter  Mumbai Indians
# 3               Bowler  Mumbai Indians
# 4               Bowler  Mumbai Indians

# %%
df_pl.drop("Unnamed: 0", axis=1,inplace=True)

# %%
df_pl.head()
# Out:
#           PlayerName    BattingStyle          BowlingStyle  \
# 0       Rohit Sharma  Right hand Bat    Right arm Offbreak
# 1  Jason Behrendorff  Right hand Bat  Left arm Fast medium
# 2          Tim David  Right hand Bat    Right arm Offbreak
# 3        Duan Jansen  Right hand Bat         Left arm Fast
# 4        Arshad Khan   Left hand Bat       Left arm Medium
#
#            PlayingRole            Team
# 0     Top order Batter  Mumbai Indians
# 1               Bowler  Mumbai Indians
# 2  Middle order Batter  Mumbai Indians
# 3               Bowler  Mumbai Indians
# 4               Bowler  Mumbai Indians
